# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')


# GitHub raw CSV file URL
csv_url = "https://raw.githubusercontent.com/RoseWairimuK/Files/main/gdp_dataset.csv"

# Load the CSV file into a DataFrame from the URL
df = pd.read_csv(csv_url)

# Print the first few rows of the DataFrame
print("First few rows of the dataset:")
df.head()
# Out:
# First few rows of the dataset:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area_Sq_m  Pop. Density_per_sq_m  Coastline_coast_area_ratio  \
# 0     647500                   48.0                        0.00
# 1      28748                  124.6                        1.26
# 2    2381740                   13.8                        0.04
# 3        199                  290.4                       58.29
# 4        468                  152.1                        0.00
#
#    Net migration  Infant_mortality_per_1000_births  GDP_$_per_capita  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area_Sq_m', 'Pop. Density_per_sq_m',
#        'Coastline_coast_area_ratio', 'Net migration',
#        'Infant_mortality_per_1000_births', 'GDP_$_per_capita', 'Literacy_%',
#        'Phones_per_1000', 'Arable_%', 'Crops_%', 'Other_%', ' Climate ',
#        'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'Year'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                              object
# Region                               object
# Population                            int64
# Area_Sq_m                             int64
# Pop. Density_per_sq_m               float64
# Coastline_coast_area_ratio          float64
# Net migration                       float64
# Infant_mortality_per_1000_births    float64
# GDP_$_per_capita                    float64
# Literacy_%                          float64
# Phones_per_1000                     float64
# Arable_%                            float64
# Crops_%                             float64
# Other_%                             float64
#  Climate                            float64
# Birthrate                           float64
# Deathrate                           float64
# Agriculture                         float64
# Industry                            float64
# Service                             float64
# Year                                  int64
# dtype: object

# %%
import streamlit as st
import pandas as pd
import plotly.express as px





# Load the dataset containing country names, latitudes, and longitudes
latlong_url = "https://gist.githubusercontent.com/ofou/df09a6834a8421b4f376c875194915c9/raw/355eb56e164ddc3cd1a9467c524422cb674e71a9/country-capital-lat-long-population.csv"
df_latlong = pd.read_csv(latlong_url)

# Merge the datasets based on the 'Country' column
df_merged = pd.merge(df_gdp, df_latlong[['Country', 'Latitude', 'Longitude']], on='Country', how='left')

# Create a new section called "Country Analysis" enclosed in an expander
with st.expander("Country Analysis", expanded=True):
    # Get unique values of the selected feature
    selected_feature = st.selectbox("Select Feature", options=df_merged.columns)

    # Filter dataset specifically for the year 2018
    df_2018 = df_merged[df_merged["Year"] == 2018]

    # Plot countries on the map using Plotly
    fig = px.scatter_geo(df_2018, 
                         locations="Country", 
                         locationmode="country names",
                         lon="Longitude",
                         lat="Latitude",
                         color=selected_feature,
                         hover_name="Country",
                         title=f"{selected_feature} by Country (2018)")
    
    # Show the map
    st.plotly_chart(fig)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 import plotly.express as px
#
# ModuleNotFoundError: No module named 'streamlit'
